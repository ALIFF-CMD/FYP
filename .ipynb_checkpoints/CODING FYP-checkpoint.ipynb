# %%
import pandas as pd
import string
import pandas as pd
import re
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pejua\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
file_path = "C:/Users/pejua/Documents/UMS/FYP 1/DATASET/FYP1/stemmed_data.csv"
data = pd.read_csv(file_path)

# %%
data_info = data.info()
data_head = data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184354 entries, 0 to 184353
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   is_offensive    184354 non-null  int64
#  1   text            184349 non-null  object
#  2   tokenized_text  184354 non-null  object
#  3   stemmed_text    184341 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 5.6+ MB

# %%
print(data.head())
# Out:
#    is_offensive                                               text  \
# 0             0  then go to the village pump and suggest they c...
# 1             1  anti greek nationalis wikipedia \n\nhi alexiko...
# 2             1     dis hoe wasnt dis violent on lottery ticket 😂😂
# 3             0  it is better for atabay not helping the banned...
# 4             0  is in camelcase  sicko is not camelcase so the...
#
#                                       tokenized_text  \
# 0  ['then', 'go', 'to', 'the', 'village', 'pump',...
# 1  ['anti', 'greek', 'nationalis', 'wikipedia', '...
# 2  ['dis', 'hoe', 'wasnt', 'dis', 'violent', 'on'...
# 3  ['it', 'is', 'better', 'for', 'atabay', 'not',...
# 4  ['is', 'in', 'camelcase', 'sicko', 'is', 'not'...
#
#                                         stemmed_text
# 0  then go to the villag pump and suggest they ch...
# 1  anti greek nationali wikipedia hi alexikoua yo...
# 2     dis hoe wasnt dis violent on lotteri ticket 😂😂
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import string

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pejua\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pejua\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
missing_values_count = data.isnull().sum()
print("Missing values in each column:")
print(missing_values_count)
# Out:
# Missing values in each column:
# is_offensive       0
# text               5
# tokenized_text     0
# stemmed_text      13
# dtype: int64

# %%
rows_with_missing_values = data[data.isnull().any(axis=1)]
print("Rows with missing values:")
print(rows_with_missing_values)
# Out:
# Rows with missing values:
#         is_offensive    text tokenized_text stemmed_text
# 33230              0                     []          NaN
# 79960              0                     []          NaN
# 98502              0   \n \n             []          NaN
# 102193             0     NaN        ['nan']          NaN
# 106865             0                     []          NaN
# 112859             0                     []          NaN
# 116698             0   \n                []          NaN
# 122526             0     NaN        ['nan']          NaN
# 133644             0     NaN             []          NaN
# 141613             0      \n             []          NaN
# 149353             0                     []          NaN
# 154264             0     NaN        ['nan']          NaN
# 170295             0     NaN        ['nan']          NaN

# %%
data = data.dropna(subset=['text'])

# %%
missing_values_count = data.isnull().sum()
print("Missing values in each column:")
print(missing_values_count)
# Out:
# Missing values in each column:
# is_offensive      0
# text              0
# tokenized_text    0
# stemmed_text      8
# dtype: int64

# %%
data['text'] = data['text'].str.lower()

# %%
data.loc[:, 'text'] = data['text'].str.replace(f"[{string.punctuation}]", "", regex=True)

# %%
def remove_stop_words(text):
    return ' '.join(word for word in text.split() if word.lower() not in stop_words)

# %%
def simple_tokenize(text):
    # Split text into words based on whitespace and punctuation
    tokens = re.findall(r'\b\w+\b', text.lower())
    return tokens

# %%
stemmer = SnowballStemmer('english')

# %%
stop_words = set([
    "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves",
    "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their",
    "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was",
    "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and",
    "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between",
    "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off",
    "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any",
    "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
    "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"
])

# %%
def stem_text(text):
    # Tokenize the text
    words = word_tokenize(text)
    # Stem each word
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)

# %%
import pandas as pd
import re
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pejua\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stemmer = SnowballStemmer('english')

# %%
data['text'] = data['text'].astype(str)

# %%
def simple_tokenize(text):
    # Split text into words based on whitespace and punctuation
    tokens = re.findall(r'\b\w+\b', text.lower())
    return tokens

# %%
def stem_text(text):
    
    words = word_tokenize(text)
    
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)

# %%
def simple_tokenize(text):
    if isinstance(text, float):
        text = str(text)
    
    tokens = re.findall(r'\b\w+\b', text.lower())
    return tokens

# %%
data.loc[:, 'tokenized_text'] = data['text'].apply(simple_tokenize)

# %%
data.loc[:, 'stemmed_text'] = data['text'].apply(stem_text)

# %%
print(data.head())
# Out:
#    is_offensive                                               text  \
# 0             0  then go to the village pump and suggest they c...
# 1             1  anti greek nationalis wikipedia \n\nhi alexiko...
# 2             1     dis hoe wasnt dis violent on lottery ticket 😂😂
# 3             0  it is better for atabay not helping the banned...
# 4             0  is in camelcase  sicko is not camelcase so the...
#
#                                       tokenized_text  \
# 0  [then, go, to, the, village, pump, and, sugges...
# 1  [anti, greek, nationalis, wikipedia, hi, alexi...
# 2  [dis, hoe, wasnt, dis, violent, on, lottery, t...
# 3  [it, is, better, for, atabay, not, helping, th...
# 4  [is, in, camelcase, sicko, is, not, camelcase,...
#
#                                         stemmed_text
# 0  then go to the villag pump and suggest they ch...
# 1  anti greek nationali wikipedia hi alexikoua yo...
# 2     dis hoe wasnt dis violent on lotteri ticket 😂😂
# ...

# %%
output_file_path = 'C:/Users/pejua/Documents/UMS/FYP 1/DATASET/stemmed_data.csv'
data.to_csv(output_file_path, index=False)

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# %%
file_path = "C:/Users/pejua/Documents/UMS/FYP 1/DATASET/FYP1/stemmed_data.csv"
data = pd.read_csv(file_path)

# %%
data['stemmed_text'] = data['stemmed_text'].fillna('')

# %%
bow_vectorizer = CountVectorizer()
X_bow = bow_vectorizer.fit_transform(data['stemmed_text'])

# %%
tfidf_vectorizer = TfidfVectorizer()
X_tfidf = tfidf_vectorizer.fit_transform(data['stemmed_text'])

# %%
print(data.columns)
# Out:
# Index(['is_offensive', 'text', 'tokenized_text', 'stemmed_text'], dtype='object')

# %%
X_train_bow, X_test_bow, y_train_bow, y_test_bow = train_test_split(X_bow, data['is_offensive'], test_size=0.2, random_state=42)

# %%
svm_bow = SVC(kernel='linear')
svm_bow.fit(X_train_bow, y_train_bow)
y_pred_bow = svm_bow.predict(X_test_bow)
print("Bag of Words - Accuracy:", accuracy_score(y_test_bow, y_pred_bow))
print("Bag of Words - Classification Report:")
print(classification_report(y_test_bow, y_pred_bow))
# Out:
# Bag of Words - Accuracy: 0.9568224349759974
# Bag of Words - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     29514
#            1       0.91      0.87      0.89      7357
#
#     accuracy                           0.96     36871
#    macro avg       0.94      0.92      0.93     36871
# weighted avg       0.96      0.96      0.96     36871

# %%
X_train_bow, X_test_bow, y_train_bow, y_test_bow = train_test_split(X_bow, data['is_offensive'], test_size=0.3, random_state=42)

# %%
svm_bow = SVC(kernel='linear')
svm_bow.fit(X_train_bow, y_train_bow)
y_pred_bow = svm_bow.predict(X_test_bow)
print("Bag of Words - Accuracy:", accuracy_score(y_test_bow, y_pred_bow))
print("Bag of Words - Classification Report:")
print(classification_report(y_test_bow, y_pred_bow))
# Out:
# Bag of Words - Accuracy: 0.9559187806245141
# Bag of Words - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     44267
#            1       0.91      0.86      0.89     11040
#
#     accuracy                           0.96     55307
#    macro avg       0.94      0.92      0.93     55307
# weighted avg       0.96      0.96      0.96     55307

# %%
X_train_tfidf, X_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(X_tfidf, data['is_offensive'], test_size=0.3, random_state=42)

# %%
svm_tfidf = SVC(kernel='linear')
svm_tfidf.fit(X_train_tfidf, y_train_tfidf)
y_pred_tfidf = svm_tfidf.predict(X_test_tfidf)
print("TF-IDF - Accuracy:", accuracy_score(y_test_tfidf, y_pred_tfidf))
print("TF-IDF - Classification Report:")
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# TF-IDF - Accuracy: 0.9609091073462672
# TF-IDF - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     44267
#            1       0.96      0.84      0.90     11040
#
#     accuracy                           0.96     55307
#    macro avg       0.96      0.91      0.94     55307
# weighted avg       0.96      0.96      0.96     55307

# %%
X_train_tfidf, X_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(X_tfidf, data['is_offensive'], test_size=0.2, random_state=42)

# %%
svm_tfidf = SVC(kernel='linear')
svm_tfidf.fit(X_train_tfidf, y_train_tfidf)
y_pred_tfidf = svm_tfidf.predict(X_test_tfidf)
print("TF-IDF - Accuracy:", accuracy_score(y_test_tfidf, y_pred_tfidf))
print("TF-IDF - Classification Report:")
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# TF-IDF - Accuracy: 0.9612161319193947
# TF-IDF - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     29514
#            1       0.96      0.84      0.90      7357
#
#     accuracy                           0.96     36871
#    macro avg       0.96      0.92      0.94     36871
# weighted avg       0.96      0.96      0.96     36871

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

# %%
X_train_tfidf, X_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(
    X_tfidf, data['is_offensive'], test_size=0.2, random_state=42)

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],  
    'kernel': ['linear', 'rbf', 'poly'],  
    'gamma': ['scale', 'auto'],  
    'degree': [2, 3, 4], }

# %%
svm_model = SVC()

# %%
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=5, verbose=2, n_jobs=-1)

# %%
grid_search.fit(X_train_tfidf, y_train_tfidf)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              verbose=2)

# %%
print("Best Parameters: ", grid_search.best_params_)
# Out:
# Best Parameters:  {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %%
y_pred_tfidf = grid_search.predict(X_test_tfidf)

# %%
print("Accuracy: ", accuracy_score(y_test_tfidf, y_pred_tfidf))
print("Classification Report: ")
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# Accuracy:  0.9612161319193947
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     29514
#            1       0.96      0.84      0.90      7357
#
#     accuracy                           0.96     36871
#    macro avg       0.96      0.92      0.94     36871
# weighted avg       0.96      0.96      0.96     36871

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
nb_tfidf = MultinomialNB()
nb_tfidf.fit(X_train_tfidf, y_train_tfidf)
y_pred_nb_tfidf = nb_tfidf.predict(X_test_tfidf)
print("Naive Bayes (TF-IDF) - Accuracy:", accuracy_score(y_test_tfidf, y_pred_nb_tfidf))
print("Naive Bayes (TF-IDF) - Classification Report:")
print(classification_report(y_test_tfidf, y_pred_nb_tfidf))
# Out:
# Naive Bayes (TF-IDF) - Accuracy: 0.9073255403976025
# Naive Bayes (TF-IDF) - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     29514
#            1       0.97      0.55      0.70      7357
#
#     accuracy                           0.91     36871
#    macro avg       0.93      0.77      0.82     36871
# weighted avg       0.91      0.91      0.90     36871

# %%
nb_bow = MultinomialNB()
nb_bow.fit(X_train_bow, y_train_bow)
y_pred_nb_bow = nb_bow.predict(X_test_bow)
print("Naive Bayes (BoW) - Accuracy:", accuracy_score(y_test_bow, y_pred_nb_bow))
print("Naive Bayes (BoW) - Classification Report:")
print(classification_report(y_test_bow, y_pred_nb_bow))
# Out:
# Naive Bayes (BoW) - Accuracy: 0.9251450991737031
# Naive Bayes (BoW) - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95     44267
#            1       0.80      0.83      0.82     11040
#
#     accuracy                           0.93     55307
#    macro avg       0.88      0.89      0.88     55307
# weighted avg       0.93      0.93      0.93     55307

# %%
lr_tfidf = LogisticRegression(max_iter=1000)
lr_tfidf.fit(X_train_tfidf, y_train_tfidf)
y_pred_lr_tfidf = lr_tfidf.predict(X_test_tfidf)
print("Logistic Regression (TF-IDF) - Accuracy:", accuracy_score(y_test_tfidf, y_pred_lr_tfidf))
print("Logistic Regression (TF-IDF) - Classification Report:")
print(classification_report(y_test_tfidf, y_pred_lr_tfidf))
# Out:
# Logistic Regression (TF-IDF) - Accuracy: 0.9555748420167611
# Logistic Regression (TF-IDF) - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     29514
#            1       0.96      0.81      0.88      7357
#
#     accuracy                           0.96     36871
#    macro avg       0.96      0.90      0.93     36871
# weighted avg       0.96      0.96      0.95     36871

# %%
lr_bow = LogisticRegression(max_iter=1000)
lr_bow.fit(X_train_bow, y_train_bow)
y_pred_lr_bow = lr_bow.predict(X_test_bow)
print("Logistic Regression (BoW) - Accuracy:", accuracy_score(y_test_bow, y_pred_lr_bow))
print("Logistic Regression (BoW) - Classification Report:")
print(classification_report(y_test_bow, y_pred_lr_bow))
# Out:
# Logistic Regression (BoW) - Accuracy: 0.9571844431988717
# Logistic Regression (BoW) - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     44267
#            1       0.93      0.84      0.89     11040
#
#     accuracy                           0.96     55307
#    macro avg       0.95      0.91      0.93     55307
# weighted avg       0.96      0.96      0.96     55307

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
nb_model = MultinomialNB()
param_grid = {'alpha': [0.01, 0.1, 1, 10]}
grid_search_nb = GridSearchCV(estimator=nb_model, param_grid=param_grid, cv=5)
grid_search_nb.fit(X_train_tfidf, y_train_tfidf)
# Out:
# GridSearchCV(cv=5, estimator=MultinomialNB(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10]})

# %%
print("Best Parameters for Naive Bayes: ", grid_search_nb.best_params_)
# Out:
# Best Parameters for Naive Bayes:  {'alpha': 0.1}

# %%
logistic_model = LogisticRegression(max_iter=500)
param_grid_lr = [
    {'C': [0.01, 0.1, 1, 10], 'solver': ['liblinear'], 'penalty': ['l1', 'l2']},  
    {'C': [0.01, 0.1, 1, 10], 'solver': ['lbfgs'], 'penalty': ['l2']}  
]
grid_search_lr = GridSearchCV(estimator=LogisticRegression(max_iter=500), param_grid=param_grid_lr, cv=5)
grid_search_lr.fit(X_train_tfidf, y_train_tfidf)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=500),
#              param_grid=[{'C': [0.01, 0.1, 1, 10], 'penalty': ['l1', 'l2'],
#                           'solver': ['liblinear']},
#                          {'C': [0.01, 0.1, 1, 10], 'penalty': ['l2'],
#                           'solver': ['lbfgs']}])

# %%
print("Best Parameters for Logistic Regression: ", grid_search_lr.best_params_)
print("Best Score for Logistic Regression: ", grid_search_lr.best_score_)
# Out:
# Best Parameters for Logistic Regression:  {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Score for Logistic Regression:  0.9588833940985702

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test_tfidf, y_pred_tfidf)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Non-Toxic', 'Toxic'], yticklabels=['Non-Toxic', 'Toxic'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - SVM (TF-IDF)")
plt.show()

# %%
# Compute confusion matrix
cm_bow = confusion_matrix(y_test_bow, y_pred_bow)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm_bow, annot=True, fmt="d", cmap="Blues", xticklabels=['Non-Toxic', 'Toxic'], yticklabels=['Non-Toxic', 'Toxic'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - SVM (BoW)")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Not Offensive", "Offensive"], yticklabels=["Not Offensive", "Offensive"])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(title)
    plt.show()

# Confusion Matrix for SVM (TF-IDF)
plot_confusion_matrix(y_test_tfidf, y_pred_tfidf, "SVM (TF-IDF)")

# Confusion Matrix for SVM (BoW)
plot_confusion_matrix(y_test_bow, y_pred_bow, "SVM (BoW)")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Not Offensive", "Offensive"], yticklabels=["Not Offensive", "Offensive"])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(title)
    plt.show()

# Confusion Matrix for Naive Bayes (TF-IDF)
plot_confusion_matrix(y_test_tfidf, y_pred_nb_tfidf, "Naive Bayes (TF-IDF)")

# Confusion Matrix for Naive Bayes (BoW)
plot_confusion_matrix(y_test_bow, y_pred_nb_bow, "Naive Bayes (BoW)")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Not Offensive", "Offensive"], yticklabels=["Not Offensive", "Offensive"])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(title)
    plt.show()

# Confusion Matrix for Logistic Regression (TF-IDF)
plot_confusion_matrix(y_test_tfidf, y_pred_lr_tfidf, "Logistic Regression (TF-IDF)")

# Confusion Matrix for Logistic Regression (BoW)
plot_confusion_matrix(y_test_bow, y_pred_lr_bow, "Logistic Regression (BoW)")

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(y_true, y_pred, model_name):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    
    print(f"\n{model_name} Performance:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    return accuracy, precision, recall, f1

# Evaluate SVM
evaluate_model(y_test_tfidf, y_pred_tfidf, "SVM (TF-IDF)")
evaluate_model(y_test_bow, y_pred_bow, "SVM (BoW)")

# Evaluate Naive Bayes
evaluate_model(y_test_tfidf, y_pred_nb_tfidf, "Naive Bayes (TF-IDF)")
evaluate_model(y_test_bow, y_pred_nb_bow, "Naive Bayes (BoW)")

# Evaluate Logistic Regression
evaluate_model(y_test_tfidf, y_pred_lr_tfidf, "Logistic Regression (TF-IDF)")
evaluate_model(y_test_bow, y_pred_lr_bow, "Logistic Regression (BoW)")
# Out:
# SVM (TF-IDF) Performance:
# Accuracy: 0.9612
# Precision: 0.9618
# Recall: 0.8389
# F1-score: 0.8962
#
# SVM (BoW) Performance:
# Accuracy: 0.9559
# Precision: 0.9106
# Recall: 0.8640
# F1-score: 0.8867
#
# Naive Bayes (TF-IDF) Performance:
# Accuracy: 0.9073
# Precision: 0.9684
# Recall: 0.5536
# F1-score: 0.7045
#
# Naive Bayes (BoW) Performance:
# Accuracy: 0.9251
# Precision: 0.7993
# Recall: 0.8345
# F1-score: 0.8165
#
# Logistic Regression (TF-IDF) Performance:
# Accuracy: 0.9556
# Precision: 0.9632
# Recall: 0.8082
# F1-score: 0.8789
#
# Logistic Regression (BoW) Performance:
# Accuracy: 0.9572
# Precision: 0.9349
# Recall: 0.8443
# F1-score: 0.8873
# (0.9571844431988717,
#  0.9349047141424273,
#  0.8442934782608695,
#  0.8872917658257972)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Load your dataset
file_path = "C:/Users/pejua/Documents/UMS/FYP 1/DATASET/FYP1/stemmed_data.csv"  # Update this if needed
data = pd.read_csv(file_path)

# Ensure the 'text' column exists
if "text" in data.columns:
    text_data = " ".join(data["text"].astype(str))  # Combine all text data into one string

    # Generate Word Cloud
    wordcloud = WordCloud(width=800, height=400, background_color="white", colormap="viridis").generate(text_data)

    # Display the Word Cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")  # Hide axes
    plt.title("Word Cloud for FYP Dataset")
    plt.show()
else:
    print("Column 'text' not found in dataset!")
